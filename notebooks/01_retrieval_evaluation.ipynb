# %% [markdown]
# # Évaluation Retrieval — BM25 vs Vector vs Hybrid
#
# Charge les résultats produits par .

# %%
import json, pandas as pd
with open("../data/eval_results/retrieval_evaluation.json") as f:
    results = json.load(f)
pd.DataFrame(results["results"]).T
# Out:
#         hit_rate@k     mrr@k
# bm25          0.63  0.416333
# vector        0.65  0.495667
# hybrid        0.70  0.477667

# %% [markdown]
# ## Conclusion
#
# Aprés analyse du `hit_rate` et `mrr` sur les méthodes de recherche , l'hybrid est meilleur.
